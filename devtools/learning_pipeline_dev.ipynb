# %%
# %load_ext autoreload
# %autoreload 2

import sys, os
sys.path.append("../")

import numpy as np
import math
import pickle
from config import *
from iotools.readOxford import ReadOxford
from iotools.readrpkm import ReadRPKM
from iotools.io_model import WriteModel
from inference.linreg_association import LinRegAssociation
from inference.empirical_bayes import EmpiricalBayes
from utils import hyperparameters
from inference import logmarglik
from iotools import readgtf
from utils import gtutils
from utils import mfunc
from utils.containers import ZstateInfo
from utils.printstamp import printStamp
from helper_functions import load_target_genes, write_params
from sklearn.preprocessing import scale
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Annotation (use complete gene name in gtf without trimming the version)
# load annotation for whole genome
gene_info = readgtf.gencode_v12(gtfpath, trim=False)

# %%
# Load gene list
genelistfile = "genes4testing_high_and_low_r2_0.001"
selected_gene_ids = load_target_genes(genelistfile, gene_info, chrom)
# Out:
# Read 641 genes with high r2 values
#
# Found 57 genes in CHR 12

# %%
if not os.path.exists(learn_pickfile):
    # read Genotype
    oxf = ReadOxford(gtex_gtpath, gtex_samplepath, chrom, learning_dataset)
    genotype = np.array(oxf.dosage)
    samplenames = oxf.samplenames
    snps = oxf.snps_info

    printStamp("Dumping CHR {:d} genotype".format(chrom))
    with open(learn_pickfile, 'wb') as output:
        pickle.dump(oxf, output, pickle.HIGHEST_PROTOCOL)
else:
    printStamp("Reading pickled genotype")
    with open(learn_pickfile, 'rb') as input:
        pickled_oxf = pickle.load(input)

    printStamp("Done reading")

    genotype = np.array(pickled_oxf.dosage)
    samplenames = pickled_oxf.samplenames
    snps = pickled_oxf.snps_info
    nsample = len(pickled_oxf.samplenames)

# Quality control
f_snps, f_genotype = gtutils.remove_low_maf(snps, genotype, 0.1)
gt = gtutils.normalize(f_snps, f_genotype)

# Gene Expression
rpkm = ReadRPKM(gtex_rpkmpath, "gtex")
expression = rpkm.expression
expr_donors = rpkm.donor_ids
gene_names = rpkm.gene_names

# Selection
printStamp("Selection of samples")
vcfmask, exprmask = mfunc.select_donors(samplenames, expr_donors)
genes, indices = mfunc.select_genes(gene_info, gene_names)

gene_training_list = []
for i, gene in enumerate(genes):
    k = indices[i]
    if gene.ensembl_id in selected_gene_ids and gene.chrom == chrom:
        gene_training_list.append((k,gene))
        # print(k,gene)
# Out:
# 2018-03-24 16:56:52 - Reading pickled genotype
# 2018-03-24 16:57:32 - Done reading
# 2018-03-24 16:57:39 - Selection of samples

# %%
gene_training_12 = []
for i, gene in enumerate(genes):
    k = indices[i]
    if gene.chrom == chrom:
        gene_training_12.append((k,gene))
        # print(k,gene)

# %%
print(len(gene_training_12))
print(len(genes))
# Out:
# 831
# 14810

# %%
parameters[0]
# Out:
# ['gxpred-bslmm',
#  [0.005, 0.0, 0.1, 0.001, 0.005],
#  [None, None, None, 'L1', None],
#  {'lambda': 0.1},
#  'unbound_L1_0.1']

# %%
p = parameters[0]

prior = p[0]
params = p[1]
hyperpriors = p[2]
hyperparams = p[3]
run_description = p[4]
init_params = np.array(params)
# account for Tau inverse value
init_params[4] = 1 / init_params[4] / init_params[4]

model_dir = prior+"_{:.3f}_{:.3f}_{:.3f}_{:.3f}_{:.3f}".format(params[0], params[1], params[2], params[3], params[4])
modelpath = os.path.join("./z"+str(zmax), run_description, model_dir)
write_params(modelpath, p)

model = WriteModel(modelpath, chrom)

for i in range(0,len(gene_training_list)):

    k, gene = gene_training_list[i]

    print(k, gene)

    # select only the cis-SNPs
    cismask = mfunc.select_snps(gene, f_snps, window)
    if len(cismask) > 0:
        target = expression[k, exprmask]
        target = scale(target, with_mean=True, with_std=True)
        predictor = gt[cismask][:, vcfmask]
        snpmask = cismask

        # if number of cis SNPs > threshold, use p-value cut-off
        if len(cismask) > min_snps:
            assoc_model = LinRegAssociation(predictor, target, min_snps, pval_cutoff)
            pvalmask = cismask[assoc_model.selected_variables]
            print ("Found {:d} SNPs, reduced to {:d} SNPs (max p-value {:g}) for {:s}".format(len(cismask), len(pvalmask), assoc_model.ordered_pvals[len(pvalmask) - 1], gene.name))
            predictor = gt[pvalmask][:, vcfmask]
            snpmask = pvalmask
        else:
            print ("Found {:d} SNPs for {:s}".format(len(cismask), gene.name))

        # perform the analysis

        print ("Starting first optimization ==============")
        emp_bayes = EmpiricalBayes(predictor, target, 1, init_params, method="new", prior=prior, hyperpriors= hyperpriors, hyperparams= hyperparams)
        emp_bayes.fit()
        if zmax > 1:
            if emp_bayes.success:
                res = emp_bayes.params
                print ("Starting second optimization from previous results ================")
                # Python Error: C library could not compute z-components. Check C errors above.
            else:
                res = init_params
                print ("Starting second optimization from initial parameters ================")
            emp_bayes = EmpiricalBayes(predictor, target, zmax, res, method="new", prior=prior, hyperpriors= hyperpriors, hyperparams= hyperparams)
            emp_bayes.fit()

        if emp_bayes.success:
            res = emp_bayes.params
            res[4] = 1 / np.sqrt(res[4])
            print("PI: \t",res[0])
            print("mu: \t",res[1])
            print("sigma: \t",res[2])
            print("sigmabg: \t",res[3])
            print("tau: \t",res[4])

            model_snps = [f_snps[x] for x in snpmask]
            model_zstates = list()
            scaledparams = hyperparameters.scale(emp_bayes.params)
            zprob, zexp = logmarglik.model_exp(scaledparams, predictor, target, emp_bayes.zstates, prior)
            for j, z in enumerate(emp_bayes.zstates):
                this_zstate = ZstateInfo(state = z,
                                         prob  = zprob[j],
                                         exp   = list(zexp[j, :]) )
                model_zstates.append(this_zstate)
            # print(model_snps)
            # for i,m in enumerate(model_zstates):
            #     print("z-state: ",i," Prob:", m.prob)
            model.write_success_gene(gene, model_snps, model_zstates, res)
        else:
            model.write_failed_gene(gene, np.zeros_like(init_params))
            print ("Failed optimization")
# Out:
# 13866 GeneInfo(name='C3AR1', ensembl_id='ENSG00000171860.4', chrom=12, start=8210898, end=8219066)
# Found 3603 SNPs, reduced to 200 SNPs (max p-value 0.0297755) for C3AR1
# Starting first optimization ==============
# Selected method: new, prior: gxpred-bslmm
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 4 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
#       fun: 342.9386390311496
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.41398004e-16, -1.44549666e-05,  1.44895733e-06,  3.02153652e-04,
#        -5.46343770e-03])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 94
#       nit: 76
#    status: 0
#   success: True
#         x: array([-5.29330482, 72.25961743, -9.59197088, -4.33270095, -0.43572326])
# PI: 	 0.005000000000000001
# mu: 	 0.7225961743398845
# sigma: 	 6.827472790827797e-05
# sigmabg: 	 0.013132030623973275
# tau: 	 0.6467966958379634
# 13883 GeneInfo(name='CLEC6A', ensembl_id='ENSG00000205846.3', chrom=12, start=8608521, end=8630926)
# Found 4007 SNPs, reduced to 200 SNPs (max p-value 0.00476416) for CLEC6A
# Starting first optimization ==============
# Selected method: new, prior: gxpred-bslmm
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 4 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 6 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 7 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 30 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 43 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 59 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 91 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 102 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 105 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 105 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 105 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 104 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 101 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 96 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 93 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 92 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 92 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 92 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 92 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 92 leading zstates.
# Old probsum: 0.769836, target: 0.980000
# Working with 161 leading zstates.
# Old probsum: 0.770524, target: 0.980000
# Working with 161 leading zstates.
# Old probsum: 0.896102, target: 0.980000
# Working with 121 leading zstates.
# Old probsum: 0.893446, target: 0.980000
# Working with 125 leading zstates.
# Old probsum: 0.896216, target: 0.980000
# Working with 123 leading zstates.
# Old probsum: 0.906538, target: 0.980000
# Working with 117 leading zstates.
# Old probsum: 0.921511, target: 0.980000
# Working with 107 leading zstates.
# Old probsum: 0.938816, target: 0.980000
# Working with 91 leading zstates.
# Old probsum: 0.955627, target: 0.980000
# Working with 67 leading zstates.
# Old probsum: 0.966246, target: 0.980000
# Working with 44 leading zstates.
# Old probsum: 0.979406, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.988618, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.994790, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.996863, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.997768, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.998660, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999219, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999450, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999713, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999835, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999914, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999914, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999956, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999978, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999989, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999994, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999997, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999999, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999999, target: 0.980000
# Working with 2 leading zstates.
#       fun: 447.5661952016677
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.14988902e-06, -2.10002890e-09, -6.40621968e-09,  1.90997304e-03,
#         4.33341221e-03])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 66
#       nit: 56
#    status: 0
#   success: True
#         x: array([-18.96513233,   0.31613491,  -3.03737685,  -3.0094873 ,
#         -0.1386691 ])
# PI: 	 5.801598627521058e-09
# mu: 	 0.0031613490870790145
# sigma: 	 0.047960532437977245
# sigmabg: 	 0.049316957319676794
# tau: 	 0.870516038027342
# 13884 GeneInfo(name='CLEC4D', ensembl_id='ENSG00000166527.3', chrom=12, start=8662070, end=8674962)
# Found 4076 SNPs, reduced to 200 SNPs (max p-value 0.00116033) for CLEC4D
# Starting first optimization ==============
# Selected method: new, prior: gxpred-bslmm
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 9 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 12 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 13 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 13 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 13 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 13 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 13 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 13 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 12 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 12 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 12 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 12 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 12 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 12 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 12 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 12 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 12 leading zstates.
# Old probsum: 0.827124, target: 0.980000
# Working with 153 leading zstates.
# Old probsum: 0.827443, target: 0.980000
# Working with 153 leading zstates.
# Old probsum: 0.825022, target: 0.980000
# Working with 153 leading zstates.
# Old probsum: 0.815723, target: 0.980000
# Working with 147 leading zstates.
# Old probsum: 0.816913, target: 0.980000
# Working with 154 leading zstates.
# Old probsum: 0.820229, target: 0.980000
# Working with 152 leading zstates.
# Old probsum: 0.819717, target: 0.980000
# Working with 152 leading zstates.
# Old probsum: 0.817137, target: 0.980000
# Working with 153 leading zstates.
# Old probsum: 0.812339, target: 0.980000
# Working with 154 leading zstates.
# Old probsum: 0.801748, target: 0.980000
# Working with 157 leading zstates.
# Old probsum: 0.797850, target: 0.980000
# Working with 161 leading zstates.
# Old probsum: 0.833312, target: 0.980000
# Working with 163 leading zstates.
# Old probsum: 0.863589, target: 0.980000
# Working with 161 leading zstates.
# Old probsum: 0.879876, target: 0.980000
# Working with 159 leading zstates.
# Old probsum: 0.898164, target: 0.980000
# Working with 155 leading zstates.
# Old probsum: 0.929540, target: 0.980000
# Working with 140 leading zstates.
# Old probsum: 0.970841, target: 0.980000
# Working with 61 leading zstates.
# Old probsum: 0.993498, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.994811, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.998462, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.998900, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999454, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999678, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999856, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999933, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999957, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999980, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999989, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999995, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999997, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999999, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999999, target: 0.980000
# Working with 2 leading zstates.
#       fun: 443.62647743817536
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.22926234e-06, -1.18424629e-09, -1.80934836e-21,  7.53855368e-04,
#         2.91783911e-03])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 71
#       nit: 61
#    status: 0
#   success: True
#         x: array([-18.90197477,   0.45596696, -17.18551703,  -3.20485161,
#         -0.13989048])
# PI: 	 6.179831809507023e-09
# mu: 	 0.004559669603313726
# sigma: 	 3.4389414620025415e-08
# sigmabg: 	 0.04056492060069656
# tau: 	 0.8694534526183895
# 13928 GeneInfo(name='CLEC12B', ensembl_id='ENSG00000256660.1', chrom=12, start=10163225, end=10171218)
# Found 4208 SNPs, reduced to 218 SNPs (max p-value 0.000950746) for CLEC12B
# Starting first optimization ==============
# Selected method: new, prior: gxpred-bslmm
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000026, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000566, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000295, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000131, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000171, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000314, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000282, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000162, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000052, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000031, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000096, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000147, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000143, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000141, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000145, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000165, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000198, target: 0.980000
# Working with 4 leading zstates.
# Old probsum: 0.000277, target: 0.980000
# Working with 4 leading zstates.
# Old probsum: 0.000599, target: 0.980000
# Working with 4 leading zstates.
# Old probsum: 0.001021, target: 0.980000
# Working with 4 leading zstates.
# Old probsum: 0.001221, target: 0.980000
# Working with 4 leading zstates.
# Old probsum: 0.000860, target: 0.980000
# Working with 4 leading zstates.
# Old probsum: 0.000003, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000003, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000001, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000003, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000002, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000003, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000005, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000003, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000004, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000003, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000003, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000004, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000004, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000004, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000004, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000004, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000004, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000003, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000004, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000004, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000004, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000004, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000004, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000004, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000004, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000004, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000004, target: 0.980000
# Working with 2 leading zstates.
#       fun: 315.4528136397617
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-1.07704972e-06, -3.80328168e-05,  2.15786748e-06,  1.56383908e-04,
#         9.67799932e-03])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 95
#       nit: 72
#    status: 0
#   success: True
#         x: array([-5.37990204, 64.48084479, -8.7514103 , -3.83893251, -0.53749632])
# PI: 	 0.004587134571851823
# mu: 	 0.6448084478990684
# sigma: 	 0.00015823800427206325
# sigmabg: 	 0.021516557845548182
# tau: 	 0.5842090953088167
# 14053 GeneInfo(name='TM7SF3', ensembl_id='ENSG00000064115.6', chrom=12, start=27126128, end=27167366)
# Found 3287 SNPs, reduced to 200 SNPs (max p-value 0.022988) for TM7SF3
# Starting first optimization ==============
# Selected method: new, prior: gxpred-bslmm
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 4 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 29 leading zstates.
# Old probsum: 0.000053, target: 0.980000
# Working with 58 leading zstates.
# Old probsum: 0.000518, target: 0.980000
# Working with 64 leading zstates.
# Old probsum: 0.000935, target: 0.980000
# Working with 67 leading zstates.
# Old probsum: 0.000995, target: 0.980000
# Working with 67 leading zstates.
# Old probsum: 0.001062, target: 0.980000
# Working with 67 leading zstates.
# Old probsum: 0.001051, target: 0.980000
# Working with 67 leading zstates.
# Old probsum: 0.000870, target: 0.980000
# Working with 66 leading zstates.
# Old probsum: 0.000599, target: 0.980000
# Working with 64 leading zstates.
# Old probsum: 0.000308, target: 0.980000
# Working with 61 leading zstates.
# Old probsum: 0.000275, target: 0.980000
# Working with 60 leading zstates.
# Old probsum: 0.000276, target: 0.980000
# Working with 60 leading zstates.
# Old probsum: 0.867814, target: 0.980000
# Working with 144 leading zstates.
# Old probsum: 0.869027, target: 0.980000
# Working with 144 leading zstates.
# Old probsum: 0.866511, target: 0.980000
# Working with 145 leading zstates.
# Old probsum: 0.851052, target: 0.980000
# Working with 148 leading zstates.
# Old probsum: 0.846987, target: 0.980000
# Working with 149 leading zstates.
# Old probsum: 0.534438, target: 0.980000
# Working with 193 leading zstates.
# Old probsum: 0.529333, target: 0.980000
# Working with 193 leading zstates.
# Old probsum: 0.529412, target: 0.980000
# Working with 193 leading zstates.
# Old probsum: 0.540811, target: 0.980000
# Working with 193 leading zstates.
# Old probsum: 0.671188, target: 0.980000
# Working with 189 leading zstates.
# Old probsum: 0.705941, target: 0.980000
# Working with 188 leading zstates.
# Old probsum: 0.811463, target: 0.980000
# Working with 180 leading zstates.
# Old probsum: 0.851476, target: 0.980000
# Working with 174 leading zstates.
# Old probsum: 0.923587, target: 0.980000
# Working with 148 leading zstates.
# Old probsum: 0.923587, target: 0.980000
# Working with 148 leading zstates.
#       fun: 447.90841907693584
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.45897841e-02, -2.97310049e-03,  1.35884103e-70, -3.86998257e-02,
#         5.08412640e-01])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 58
#       nit: 39
#    status: 0
#   success: True
#         x: array([ -7.79407639,   0.24310058, -79.9933562 ,  -3.28119036,
#         -0.14342573])
# PI: 	 0.0004119994772764012
# mu: 	 0.002431005784536304
# sigma: 	 1.8168823729823464e-35
# sigmabg: 	 0.0375834923237514
# tau: 	 0.8663851409714038
# 14119 GeneInfo(name='PRICKLE1', ensembl_id='ENSG00000139174.6', chrom=12, start=42852140, end=42984156)
# Found 3819 SNPs, reduced to 200 SNPs (max p-value 0.0209849) for PRICKLE1
# Starting first optimization ==============
# Selected method: new, prior: gxpred-bslmm
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000023, target: 0.980000
# Working with 69 leading zstates.
# Old probsum: 0.007129, target: 0.980000
# Working with 185 leading zstates.
# Old probsum: 0.056285, target: 0.980000
# Working with 192 leading zstates.
# Old probsum: 0.119043, target: 0.980000
# Working with 194 leading zstates.
# Old probsum: 0.148497, target: 0.980000
# Working with 194 leading zstates.
# Old probsum: 0.154127, target: 0.980000
# Working with 194 leading zstates.
# Old probsum: 0.154484, target: 0.980000
# Working with 194 leading zstates.
# Old probsum: 0.154926, target: 0.980000
# Working with 194 leading zstates.
# Old probsum: 0.155848, target: 0.980000
# Working with 194 leading zstates.
# Old probsum: 0.157499, target: 0.980000
# Working with 194 leading zstates.
# Old probsum: 0.160757, target: 0.980000
# Working with 194 leading zstates.
# Old probsum: 0.166987, target: 0.980000
# Working with 194 leading zstates.
# Old probsum: 0.177215, target: 0.980000
# Working with 193 leading zstates.
# Old probsum: 0.190364, target: 0.980000
# Working with 193 leading zstates.
# Old probsum: 0.206705, target: 0.980000
# Working with 193 leading zstates.
# Old probsum: 0.218829, target: 0.980000
# Working with 192 leading zstates.
# Old probsum: 0.922524, target: 0.980000
# Working with 130 leading zstates.
# Old probsum: 0.922524, target: 0.980000
# Working with 130 leading zstates.
#       fun: 473.7899891146458
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.53383796e-01, -1.02966566e-04,  5.02002674e-02, -1.04764784e+00,
#        -3.89164991e+01])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 41
#       nit: 29
#    status: 0
#   success: True
#         x: array([-6.84741126,  1.02903442, -0.73395347, -3.96954788, -0.08319699])
# PI: 	 0.0010610748247154144
# mu: 	 0.010290344235086433
# sigma: 	 0.48000753912720573
# sigmabg: 	 0.018881968079527068
# tau: 	 0.9201698654909156
# 14231 GeneInfo(name='CELA1', ensembl_id='ENSG00000139610.1', chrom=12, start=51722227, end=51740462)
# Found 2593 SNPs, reduced to 200 SNPs (max p-value 0.0562764) for CELA1
# Starting first optimization ==============
# Selected method: new, prior: gxpred-bslmm
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 6 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 11 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 13 leading zstates.
# Old probsum: 0.000001, target: 0.980000
# Working with 15 leading zstates.
# Old probsum: 0.000003, target: 0.980000
# Working with 15 leading zstates.
# Old probsum: 0.000004, target: 0.980000
# Working with 15 leading zstates.
# Old probsum: 0.000004, target: 0.980000
# Working with 15 leading zstates.
# Old probsum: 0.000004, target: 0.980000
# Working with 15 leading zstates.
# Old probsum: 0.000002, target: 0.980000
# Working with 15 leading zstates.
# Old probsum: 0.000001, target: 0.980000
# Working with 14 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 14 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 14 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 14 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 14 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 14 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 14 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 14 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 14 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 14 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 14 leading zstates.
# Old probsum: 0.688746, target: 0.980000
# Working with 169 leading zstates.
# Old probsum: 0.689321, target: 0.980000
# Working with 169 leading zstates.
# Old probsum: 0.684589, target: 0.980000
# Working with 169 leading zstates.
# Old probsum: 0.708783, target: 0.980000
# Working with 174 leading zstates.
# Old probsum: 0.702849, target: 0.980000
# Working with 171 leading zstates.
# Old probsum: 0.703179, target: 0.980000
# Working with 171 leading zstates.
# Old probsum: 0.703160, target: 0.980000
# Working with 171 leading zstates.
# Old probsum: 0.700792, target: 0.980000
# Working with 173 leading zstates.
# Old probsum: 0.695194, target: 0.980000
# Working with 175 leading zstates.
# Old probsum: 0.695673, target: 0.980000
# Working with 178 leading zstates.
# Old probsum: 0.727932, target: 0.980000
# Working with 180 leading zstates.
# Old probsum: 0.776870, target: 0.980000
# Working with 179 leading zstates.
# Old probsum: 0.808516, target: 0.980000
# Working with 177 leading zstates.
# Old probsum: 0.832149, target: 0.980000
# Working with 174 leading zstates.
# Old probsum: 0.876662, target: 0.980000
# Working with 163 leading zstates.
# Old probsum: 0.876662, target: 0.980000
# Working with 163 leading zstates.
#       fun: 458.2656349747106
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 3.27135803e-02, -4.66864488e-03,  9.33762650e-04, -1.73120703e-01,
#         9.83075261e-01])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 66
#       nit: 47
#    status: 0
#   success: True
#         x: array([-7.27683342,  1.16997061, -3.85102891, -3.69754643, -0.08548588])
# PI: 	 0.0006908937200983699
# mu: 	 0.011699706145596653
# sigma: 	 0.021257852663849847
# sigmabg: 	 0.024784261883738945
# tau: 	 0.9180661089916995
# 14448 GeneInfo(name='USP15', ensembl_id='ENSG00000135655.9', chrom=12, start=62654118, end=62811211)
# Found 3472 SNPs, reduced to 200 SNPs (max p-value 0.0153321) for USP15
# Starting first optimization ==============
# Selected method: new, prior: gxpred-bslmm
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000013, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000298, target: 0.980000
# Working with 8 leading zstates.
# Old probsum: 0.000707, target: 0.980000
# Working with 11 leading zstates.
# Old probsum: 0.000800, target: 0.980000
# Working with 12 leading zstates.
# Old probsum: 0.000877, target: 0.980000
# Working with 12 leading zstates.
# Old probsum: 0.000892, target: 0.980000
# Working with 12 leading zstates.
# Old probsum: 0.000728, target: 0.980000
# Working with 10 leading zstates.
# Old probsum: 0.000454, target: 0.980000
# Working with 9 leading zstates.
# Old probsum: 0.000171, target: 0.980000
# Working with 7 leading zstates.
# Old probsum: 0.000155, target: 0.980000
# Working with 7 leading zstates.
# Old probsum: 0.000157, target: 0.980000
# Working with 7 leading zstates.
# Old probsum: 0.000162, target: 0.980000
# Working with 7 leading zstates.
# Old probsum: 0.000189, target: 0.980000
# Working with 7 leading zstates.
# Old probsum: 0.858395, target: 0.980000
# Working with 153 leading zstates.
# Python Error: C library could not compute z-components. Check C errors above.
# Failed optimization
# 14512 GeneInfo(name='LYZ', ensembl_id='ENSG00000090382.2', chrom=12, start=69742120, end=69748014)
# Found 3375 SNPs, reduced to 390 SNPs (max p-value 0.000906572) for LYZ
# Starting first optimization ==============
# Selected method: new, prior: gxpred-bslmm
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 16 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 20 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 22 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 22 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 21 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 20 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 18 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 18 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 18 leading zstates.
# Old probsum: 0.948799, target: 0.980000
# Working with 15 leading zstates.
# Old probsum: 0.975824, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.967402, target: 0.980000
# Working with 4 leading zstates.
# Old probsum: 0.969129, target: 0.980000
# Working with 4 leading zstates.
# Old probsum: 0.968907, target: 0.980000
# Working with 4 leading zstates.
# Old probsum: 0.968875, target: 0.980000
# Working with 4 leading zstates.
# Old probsum: 0.968969, target: 0.980000
# Working with 4 leading zstates.
# Old probsum: 0.969570, target: 0.980000
# Working with 4 leading zstates.
# Old probsum: 0.971790, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.976873, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.985485, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.993444, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.997495, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.998821, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999298, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999636, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999851, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999865, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999912, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999954, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999973, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999991, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999994, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999996, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999998, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.999999, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 1.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 1.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 1.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 1.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 1.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 1.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 1.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 1.000000, target: 0.980000
# Working with 2 leading zstates.
#       fun: 374.7978598955932
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 3.43288256e-07,  1.60677799e-17,  3.16971774e-10, -3.91313655e-04,
#         1.04539220e-02])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 62
#       nit: 55
#    status: 0
#   success: True
#         x: array([-20.84991917,  -0.2117092 ,   5.68712742,  -3.74468742,
#         -0.35888895])
# PI: 	 8.810390487022018e-10
# mu: 	 -0.0021170920016438523
# sigma: 	 295.0448618800972
# sigmabg: 	 0.02364301816200874
# tau: 	 0.6984519122253918
# 14514 GeneInfo(name='YEATS4', ensembl_id='ENSG00000127337.2', chrom=12, start=69753482, end=69784576)
# Found 3438 SNPs, reduced to 200 SNPs (max p-value 0.00174264) for YEATS4
# Starting first optimization ==============
# Selected method: new, prior: gxpred-bslmm
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 14 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 18 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 19 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 20 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 24 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 28 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 28 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 28 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 26 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 22 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 21 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 20 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 20 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 20 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 20 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 20 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 20 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 20 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 20 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 20 leading zstates.
# Old probsum: 0.675410, target: 0.980000
# Working with 146 leading zstates.
# Old probsum: 0.678233, target: 0.980000
# Working with 147 leading zstates.
# Old probsum: 0.633866, target: 0.980000
# Working with 141 leading zstates.
# Old probsum: 0.679568, target: 0.980000
# Working with 146 leading zstates.
# Old probsum: 0.686000, target: 0.980000
# Working with 147 leading zstates.
# Old probsum: 0.691828, target: 0.980000
# Working with 149 leading zstates.
# Old probsum: 0.695650, target: 0.980000
# Working with 154 leading zstates.
# Old probsum: 0.685099, target: 0.980000
# Working with 161 leading zstates.
# Old probsum: 0.689892, target: 0.980000
# Working with 171 leading zstates.
# Old probsum: 0.720227, target: 0.980000
# Working with 173 leading zstates.
# Old probsum: 0.748071, target: 0.980000
# Working with 174 leading zstates.
# Old probsum: 0.768619, target: 0.980000
# Working with 175 leading zstates.
# Old probsum: 0.836438, target: 0.980000
# Working with 173 leading zstates.
# Old probsum: 0.911338, target: 0.980000
# Working with 152 leading zstates.
# Old probsum: 0.947996, target: 0.980000
# Working with 119 leading zstates.
# Old probsum: 0.982757, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.982757, target: 0.980000
# Working with 2 leading zstates.
#       fun: 444.9997945569805
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.71611915e-02,  3.15644208e-05, -2.83303666e-08,  5.85105532e-02,
#        -1.11640956e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 63
#       nit: 47
#    status: 0
#   success: True
#         x: array([-9.35668885, -0.9735804 , -7.25091984, -3.54693665, -0.12404845])
# PI: 	 8.637819943865228e-05
# mu: 	 -0.009735804018453366
# sigma: 	 0.0007095214434230108
# sigmabg: 	 0.02881276809041923
# tau: 	 0.8833370390315464
# 14522 GeneInfo(name='KCNMB4', ensembl_id='ENSG00000135643.4', chrom=12, start=70760055, end=70828072)
# Found 3803 SNPs, reduced to 200 SNPs (max p-value 0.0174416) for KCNMB4
# Starting first optimization ==============
# Selected method: new, prior: gxpred-bslmm
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 7 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 12 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 42 leading zstates.
# Old probsum: 0.000068, target: 0.980000
# Working with 85 leading zstates.
# Old probsum: 0.002720, target: 0.980000
# Working with 123 leading zstates.
# Old probsum: 0.011293, target: 0.980000
# Working with 153 leading zstates.
# Old probsum: 0.016657, target: 0.980000
# Working with 160 leading zstates.
# Old probsum: 0.017537, target: 0.980000
# Working with 161 leading zstates.
# Old probsum: 0.017715, target: 0.980000
# Working with 161 leading zstates.
# Old probsum: 0.018069, target: 0.980000
# Working with 161 leading zstates.
# Old probsum: 0.017853, target: 0.980000
# Working with 160 leading zstates.
# Old probsum: 0.016622, target: 0.980000
# Working with 157 leading zstates.
# Old probsum: 0.014972, target: 0.980000
# Working with 152 leading zstates.
# Old probsum: 0.013487, target: 0.980000
# Working with 147 leading zstates.
# Old probsum: 0.013467, target: 0.980000
# Working with 145 leading zstates.
# Old probsum: 0.013976, target: 0.980000
# Working with 145 leading zstates.
# Old probsum: 0.901541, target: 0.980000
# Working with 130 leading zstates.
# Old probsum: 0.903013, target: 0.980000
# Working with 129 leading zstates.
# Old probsum: 0.914337, target: 0.980000
# Working with 123 leading zstates.
# Old probsum: 0.935772, target: 0.980000
# Working with 105 leading zstates.
# Old probsum: 0.935772, target: 0.980000
# Working with 105 leading zstates.
#       fun: 463.7772106715186
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 8.38250603e-01, -1.77608782e-06,  4.50948562e-02, -5.62765639e-02,
#        -3.43205174e-01])
# ...
# Old probsum: 0.000072, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000107, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000207, target: 0.980000
# Working with 6 leading zstates.
# Old probsum: 0.000335, target: 0.980000
# Working with 8 leading zstates.
# Old probsum: 0.000457, target: 0.980000
# Working with 8 leading zstates.
# Old probsum: 0.000723, target: 0.980000
# Working with 9 leading zstates.
# Old probsum: 0.000925, target: 0.980000
# Working with 9 leading zstates.
# Old probsum: 0.001415, target: 0.980000
# Working with 10 leading zstates.
# Old probsum: 0.001098, target: 0.980000
# Working with 10 leading zstates.
# Old probsum: 0.001181, target: 0.980000
# Working with 10 leading zstates.
# Old probsum: 0.001116, target: 0.980000
# Working with 10 leading zstates.
# Old probsum: 0.001128, target: 0.980000
# Working with 10 leading zstates.
# Old probsum: 0.001137, target: 0.980000
# Working with 10 leading zstates.
# Old probsum: 0.001136, target: 0.980000
# Working with 10 leading zstates.
# Old probsum: 0.001180, target: 0.980000
# Working with 10 leading zstates.
# Old probsum: 0.001231, target: 0.980000
# Working with 10 leading zstates.
# Old probsum: 0.001368, target: 0.980000
# Working with 10 leading zstates.
# Old probsum: 0.001579, target: 0.980000
# Working with 10 leading zstates.
# Old probsum: 0.002038, target: 0.980000
# Working with 11 leading zstates.
# Old probsum: 0.003001, target: 0.980000
# Working with 11 leading zstates.
# Old probsum: 0.005899, target: 0.980000
# Working with 12 leading zstates.
# Old probsum: 0.053813, target: 0.980000
# Working with 19 leading zstates.
# Old probsum: 0.065804, target: 0.980000
# Working with 15 leading zstates.
# Old probsum: 0.003114, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.002222, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000003, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000013, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000013, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000014, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000003, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000004, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000004, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000005, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000005, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000004, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000005, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000005, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000005, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000005, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000005, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000005, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000005, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000005, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000005, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000005, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000005, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000005, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000005, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000005, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000005, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000005, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000005, target: 0.980000
# Working with 2 leading zstates.
#       fun: 440.1297554723716
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.73792446e-04,  6.35510562e-05,  5.92540329e-07, -9.73874010e-06,
#        -1.25179136e-03])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 104
#       nit: 81
#    status: 0
#   success: True
#         x: array([ -5.47629382, -44.66120156,  -9.759681  ,  -4.78966037,
#         -0.13642603])
# PI: 	 0.00416737098885381
# mu: 	 -0.4466120156160916
# sigma: 	 5.773303601908279e-05
# sigmabg: 	 0.008315280985673617
# tau: 	 0.8724708526570039
# 14661 GeneInfo(name='DRAM1', ensembl_id='ENSG00000136048.9', chrom=12, start=102271128, end=102405908)
# Found 2946 SNPs, reduced to 200 SNPs (max p-value 0.0119678) for DRAM1
# Starting first optimization ==============
# Selected method: new, prior: gxpred-bslmm
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 5 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 9 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 13 leading zstates.
# Old probsum: 0.000073, target: 0.980000
# Working with 43 leading zstates.
# Old probsum: 0.000949, target: 0.980000
# Working with 70 leading zstates.
# Old probsum: 0.001994, target: 0.980000
# Working with 81 leading zstates.
# Old probsum: 0.002218, target: 0.980000
# Working with 84 leading zstates.
# Old probsum: 0.002310, target: 0.980000
# Working with 84 leading zstates.
# Old probsum: 0.002351, target: 0.980000
# Working with 84 leading zstates.
# Old probsum: 0.002096, target: 0.980000
# Working with 80 leading zstates.
# Old probsum: 0.001525, target: 0.980000
# Working with 72 leading zstates.
# Old probsum: 0.000999, target: 0.980000
# Working with 63 leading zstates.
# Old probsum: 0.000712, target: 0.980000
# Working with 57 leading zstates.
# Old probsum: 0.000644, target: 0.980000
# Working with 55 leading zstates.
# Old probsum: 0.000644, target: 0.980000
# Working with 55 leading zstates.
#       fun: 470.8957167722341
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 5.26428442e-06, -3.62786598e-02,  2.65977682e-02, -1.16037450e-01,
#         4.32140462e-01])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 31
#       nit: 25
#    status: 0
#   success: True
#         x: array([-5.2939598 ,  0.06066203, -1.32648218, -6.80719813, -0.0335603 ])
# PI: 	 0.004996742578029541
# mu: 	 0.0006066203259173502
# sigma: 	 0.2654092842272144
# sigmabg: 	 0.0011057868320499596
# tau: 	 0.9669965950749175
# 14663 GeneInfo(name='CCDC53', ensembl_id='ENSG00000120860.6', chrom=12, start=102406705, end=102455926)
# Found 2792 SNPs, reduced to 256 SNPs (max p-value 0.00098426) for CCDC53
# Starting first optimization ==============
# Selected method: new, prior: gxpred-bslmm
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 3 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 6 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 29 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 63 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 91 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 98 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 99 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 100 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 99 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 96 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 89 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 82 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 80 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 80 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 80 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 80 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 80 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 80 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 79 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 80 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 80 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 80 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 80 leading zstates.
# Old probsum: 0.693677, target: 0.980000
# Working with 217 leading zstates.
# Python Error: C library could not compute z-components. Check C errors above.
# Failed optimization
# 14816 GeneInfo(name='VSIG10', ensembl_id='ENSG00000176834.9', chrom=12, start=118501398, end=118573830)
# Found 3614 SNPs, reduced to 200 SNPs (max p-value 0.017768) for VSIG10
# Starting first optimization ==============
# Selected method: new, prior: gxpred-bslmm
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
# Old probsum: 0.000000, target: 0.980000
# Working with 2 leading zstates.
#       fun: 406.49281428081247
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-2.40376547e-15,  2.81859452e-05,  5.15688204e-06,  9.89331099e-04,
#         6.70035795e-03])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 87
#       nit: 71
#    status: 0
#   success: True
#         x: array([ -5.29330482, -51.99898332,  -9.08403429,  -4.01000325,
#         -0.25913267])
# PI: 	 0.004999999999999988
# mu: 	 -0.5199898332211441
# sigma: 	 0.00011346294024582984
# sigmabg: 	 0.01813333636445338
# tau: 	 0.7717206286967702

# %% [markdown]
# # Prediction

# %%
import sys
sys.path.append("../")
import os
import pickle
from utils.printstamp import printStamp
from iotools.io_model import ReadModel
from utils.containers import GeneExpressionArray
from utils import gtutils
from utils import mfunc
import numpy as np
from config import *

# %%
if not os.path.exists(p_pickfile):
# Read genotype (quite slow for testing) use pickle below
    p_oxf = ReadOxford(p_gtpath, p_samplepath, chrom, predicting_dataset)
    p_genotype = np.array(p_oxf.dosage)
    p_samplenames = p_oxf.samplenames
    p_snps = p_oxf.snps_info
    p_nsample = len(p_oxf.samplenames)

    printStamp("Dumping CHR {:d} genotype".format(chrom))
    with open(p_pickfile, 'wb') as output:
        pickle.dump(p_oxf, output, pickle.HIGHEST_PROTOCOL)
else:
    printStamp("Reading pickled genotype")
    with open(p_pickfile, 'rb') as input:
        pickled_oxf = pickle.load(input)

    printStamp("Done reading")

    p_genotype = np.array(pickled_oxf.dosage)
    p_samplenames = pickled_oxf.samplenames
    p_snps = pickled_oxf.snps_info
    p_nsample = len(pickled_oxf.samplenames)
# Out:
# 2018-03-26 21:12:33 - Reading pickled genotype
# 2018-03-26 21:12:41 - Done reading

# %%
# Use parameters from config.py
for p in parameters:
    prior = p[0]
    params = p[1]
    hyperpriors = p[2]
    hyperparams = p[3]
    run_description = p[4]    
    model_dir = prior+"_{:.3f}_{:.3f}_{:.3f}_{:.3f}_{:.3f}".format(params[0], params[1], params[2], params[3], params[4])
    modelpath = os.path.join("./z"+str(zmax), run_description, model_dir)

    outfileprefix = os.path.join(modelpath,"pred_chr"+str(chrom))

    printStamp("Predicting for "+model_dir)
    # Write predictions for each model
    p_model = ReadModel(modelpath, chrom)
    p_genes = p_model.genes
    gx = list()
    for gene in p_genes:

        p_model.read_gene(gene)
        p_model_snps = p_model.snps
        p_model_zstates = p_model.zstates

        x = gtutils.prediction_variables(p_snps, p_model_snps, p_genotype)
        x = gtutils.normalize(p_model_snps, x)

        ypred = np.zeros(p_nsample)
        for z in p_model_zstates:
            ypred += z.prob * np.dot(x.T, z.exp)

        gx.append(GeneExpressionArray(geneid = gene.ensembl_id, expr_arr = ypred))


    # Write output
    mfunc.write_gcta_phenotype(outfileprefix, p_samplenames, gx)
# Out:
# 2018-03-26 21:12:43 - Predicting for gxpred-bslmm_0.100_0.000_0.100_0.100_0.005
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-143-e3d721982edd> in <module>()
#      22     for gene in p_genes:
#      23
# ---> 24         p_model.read_gene(gene)
#      25         p_model_snps = p_model.snps
#      26         p_model_zstates = p_model.zstates
#
# ~/gxpred/iotools/io_model.py in read_gene(self, gene)
#     147         self._setgene = gene
#     148         self._read_snps()
# --> 149         self._read_zstates()
#     150
#     151
#
# ~/gxpred/iotools/io_model.py in _read_zstates(self)
#     180                 state = ast.literal_eval(linesplit[0].strip())
#     181                 prob = float(linesplit[1].strip())
# --> 182                 exp = np.array(ast.literal_eval(linesplit[2].strip()))
#     183                 this_zstate = ZstateInfo(state = state,
#     184                                          prob  = prob,
#
# ~/myenv/lib/python3.6/ast.py in literal_eval(node_or_string)
#      46     """
#      47     if isinstance(node_or_string, str):
# ---> 48         node_or_string = parse(node_or_string, mode='eval')
#      49     if isinstance(node_or_string, Expression):
#      50         node_or_string = node_or_string.body
#
# ~/myenv/lib/python3.6/ast.py in parse(source, filename, mode)
#      33     Equivalent to compile(source, filename, mode, PyCF_ONLY_AST).
#      34     """
# ---> 35     return compile(source, filename, mode, PyCF_ONLY_AST)
#      36
#      37
#
# KeyboardInterrupt:

# %%
# Create my own parameters
# This prediction is on GTEx, to asses trans-eQTLs


# Hardcode parameters to read existing learned model
parameters = []
prior = "gxpred-bslmm"

set_init_params = [[0.1, 0.0, 0.1, 0.1, 0.005]]
run_description = "bound_mu_NoPriors"

hyperpriors = [None, None, None, None, None]
hyperparams = {"lambda":0.05, "Galpha":2, "Gbeta":0.5}
for init_params in set_init_params:
    parameters.append([prior, init_params, hyperpriors, hyperparams, run_description])

p = parameters[0]

prior = p[0]
params = p[1]
hyperpriors = p[2]
hyperparams = p[3]
run_description = p[4]
model_dir = prior+"_{:.3f}_{:.3f}_{:.3f}_{:.3f}_{:.3f}".format(params[0], params[1], params[2], params[3], params[4])
modelpath = os.path.join("./z"+str(zmax), run_description, model_dir)

outfileprefix = os.path.join(modelpath,"gtex_pred_chr"+str(chrom))

printStamp("Predicting for "+model_dir)
# Write predictions for each model
p_model = ReadModel(modelpath, chrom)
p_genes = p_model.genes
gx = list()
for gene in p_genes:

    p_model.read_gene(gene)
    p_model_snps = p_model.snps
    p_model_zstates = p_model.zstates

    x = gtutils.prediction_variables(snps, p_model_snps, genotype)
    x = gtutils.normalize(p_model_snps, x)

    ypred = np.zeros(nsample)
    for z in p_model_zstates:
        ypred += z.prob * np.dot(x.T, z.exp)

    gx.append(GeneExpressionArray(geneid = gene.ensembl_id, expr_arr = ypred))


# Write output
mfunc.write_gcta_phenotype(outfileprefix, samplenames, gx)
# Out:
# 2018-03-24 17:08:13 - Reading pickled genotype
# 2018-03-24 17:08:17 - Done reading
# 2018-03-24 17:08:18 - Predicting for gxpred-bslmm_0.100_0.000_0.100_0.100_0.005
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-119-63e06edee5b6> in <module>()
#      74
#      75 # Write output
# ---> 76 mfunc.write_gcta_phenotype(outfileprefix, p_samplenames, gx)
#
# ~/gxpred/utils/mfunc.py in write_gcta_phenotype(fileprefix, samples, gx)
#      58     with open(filepath, 'w') as pfile:
#      59         for i, sample in enumerate(samples):
# ---> 60             pheno = ['{0}'.format(x.expr_arr[i]) for x in gx]
#      61             pstr  = '\t'.join(pheno)
#      62             pfile.write('{0} \t {0} \t {1}\n'.format(sample, pstr))
#
# ~/gxpred/utils/mfunc.py in <listcomp>(.0)
#      58     with open(filepath, 'w') as pfile:
#      59         for i, sample in enumerate(samples):
# ---> 60             pheno = ['{0}'.format(x.expr_arr[i]) for x in gx]
#      61             pstr  = '\t'.join(pheno)
#      62             pfile.write('{0} \t {0} \t {1}\n'.format(sample, pstr))
#
# IndexError: index 450 is out of bounds for axis 0 with size 450

# %% [markdown]
# # Assessment

# %%
import sys
sys.path.append("../")
import os
from iotools import readgtf
from iotools.readrpkm import ReadRPKM
from iotools.readPrediction import ReadPrediction
from scipy.stats import pearsonr
from helper_functions import load_target_genes, write_r2_dataframe, get_common_elements, new_write_predicted_r2, pearson_corr_rowwise
import math
import pickle
from utils.printstamp import printStamp

from config import *

# %%
# Load reference dataset Gene Expression
reference_rpkm = ReadRPKM(reference_expdatapath, "cardiogenics")
reference_expression = reference_rpkm.expression
reference_expr_donors = reference_rpkm.donor_ids
reference_gene_names = reference_rpkm.gene_names

# %%
# use the selected_gene_ids with high R² values as targets, only those in the selected chrom will appear
selected_gene_ids = load_target_genes(genelistfile, gene_info, chrom)
target_genelist = [g.split(".")[0] for g in selected_gene_ids]
target_donors = reference_expr_donors
# Out:
# Read 641 genes with high r2 values
#
# Found 57 genes in CHR 12

# %%
### Predixcan assessment ###

if not os.path.exists(predixcan_pickfile):
    # pxpred_predpath = os.path.join(home, "predictions/cardiogenics/predixcan_predictions_klinikum")
    predixcanpred = ReadPrediction(pxpred_predpath, reference_samplepath, "predixcan", trim=True)

    printStamp("Dumping Predixcan prediction")
    with open(predixcan_pickfile, 'wb') as output:
        pickle.dump(predixcanpred, output, pickle.HIGHEST_PROTOCOL)
else:
    printStamp("Reading pickled Predixcan prediction")
    with open(predixcan_pickfile, 'rb') as input:
        predixcanpred = pickle.load(input)

# filter predixcan predictions with only those in gxpred
predixcanpred.sort_by_gene(target_genelist)
predixcanpred.sort_by_samples(target_donors, use_prev=True)

sorted_expr_donors, ix_samples = get_common_elements(reference_expr_donors, predixcanpred.sorted_samples)
sorted_gene_names, ix_genes = get_common_elements(reference_gene_names, predixcanpred.sorted_gene_names)
sorted_expression = reference_expression[ix_genes,:][:, ix_samples].T

predixcan_r = pearson_corr_rowwise(predixcanpred.sorted_expr_mat.T, sorted_expression.T)
# Out:
# 2018-03-07 11:26:27 - Reading pickled Predixcan prediction
# Genes found: 14 of 15
# Samples found: 744 of 849

# %%
# %load_ext autoreload
# %autoreload 2

### GXpred assessment ###

#for p in parameters:
p = parameters[0]
prior = p[0]
params = p[1]
hyperpriors = p[2]
hyperparams = p[3]
run_description = p[4]
model_dir = prior+"_{:.3f}_{:.3f}_{:.3f}_{:.3f}_{:.3f}".format(params[0], params[1], params[2], params[3], params[4])
print(prior, params)

modelpath = os.path.join("./z"+str(zmax), run_description, model_dir)
print(modelpath)


gxpred_predpath = os.path.join(modelpath)
gxpred = ReadPrediction(gxpred_predpath, reference_samplepath, "gxpred", trim=True)

# filter gxpred predicted values
gxpred.sort_by_gene(target_genelist)
gxpred.sort_by_samples(target_donors, use_prev=True)


# Filter and sort the reference expression values
sorted_expr_donors, ix_samples = get_common_elements(reference_expr_donors, gxpred.sorted_samples)
sorted_gene_names, ix_genes = get_common_elements(reference_gene_names, gxpred.sorted_gene_names)
sorted_expression = reference_expression[ix_genes,:][:, ix_samples].T

# Calculate Pearson correlation
gxpred_r = pearson_corr_rowwise(gxpred.sorted_expr_mat.T, sorted_expression.T)

print(gxpred.sorted_gene_names)
print(gxpred_r**2)
print(predixcan_r**2)


write_r2_dataframe(modelpath, chrom, "predixcan", predixcan_r, predixcanpred)
write_r2_dataframe(modelpath, chrom, prior, gxpred_r, gxpred)

# Write to table with predictions for given genes
# predtabledir = os.path.join(home, "gxpred","devtools", "all_predictions.txt")
# new_write_predicted_r2(predtabledir, prior, params, gxpred_r, predixcan_r, gxpred.sorted_gene_names)
# Out:
# gxpred-bslmm [0.005, 0.0, 0.1, 0.001, 0.005]
# No prediction found for CHR 1
# No prediction found for CHR 2
# No prediction found for CHR 3
# No prediction found for CHR 4
# No prediction found for CHR 5
# No prediction found for CHR 6
# No prediction found for CHR 7
# No prediction found for CHR 8
# No prediction found for CHR 9
# No prediction found for CHR 10
# No prediction found for CHR 11
# Loaded 13 genes in CHR 12
# No prediction found for CHR 13
# No prediction found for CHR 14
# No prediction found for CHR 15
# No prediction found for CHR 16
# No prediction found for CHR 17
# No prediction found for CHR 18
# No prediction found for CHR 19
# No prediction found for CHR 20
# No prediction found for CHR 21
# No prediction found for CHR 22
# Genes found: 13 of 15
# Samples found: 744 of 849

# %% [markdown]
# # Get R² on GTEx for trans eQTL

# %%
# Hardcode parameters to read existing learned model
parameters = []
prior = "gxpred-bslmm"

set_init_params = [[0.1, 0.0, 0.1, 0.1, 0.005]]
run_description = "bound_mu_NoPriors"

hyperpriors = [None, None, None, None, None]
hyperparams = {"lambda":0.05, "Galpha":2, "Gbeta":0.5}
for init_params in set_init_params:
    parameters.append([prior, init_params, hyperpriors, hyperparams, run_description])

p = parameters[0]


# Gene Expression
rpkm = ReadRPKM(gtex_rpkmpath, "gtex")
reference_expression = rpkm.expression
reference_expr_donors = rpkm.donor_ids
reference_gene_names = rpkm.gene_names



# use the selected_gene_ids with high R² values as targets, only those in the selected chrom will appear
selected_gene_ids = load_target_genes(genelistfile, gene_info, chrom)
# target_genelist = [g.split(".")[0] for g in selected_gene_ids]
target_genelist = selected_gene_ids
target_donors = reference_expr_donors


### GXpred assessment ###

#for p in parameters:
p = parameters[0]
prior = p[0]
params = p[1]
hyperpriors = p[2]
hyperparams = p[3]
run_description = p[4]
model_dir = prior+"_{:.3f}_{:.3f}_{:.3f}_{:.3f}_{:.3f}".format(params[0], params[1], params[2], params[3], params[4])
print(prior, params)

modelpath = os.path.join("./z"+str(zmax), run_description, model_dir)

gxpred_predpath = os.path.join(modelpath)
gxpred = ReadPrediction(gxpred_predpath, gtex_samplepath, "gxpred", trim=False, prefix="gtex_pred_chr")

# filter gxpred predicted values
gxpred.sort_by_gene(target_genelist)
gxpred.sort_by_samples(target_donors, use_prev=True)

# Filter and sort the reference expression values

sorted_expr_donors, ix_samples = get_common_elements(reference_expr_donors, gxpred.sorted_samples)
sorted_gene_names, ix_genes = get_common_elements(reference_gene_names, gxpred.sorted_gene_names)
sorted_expression = reference_expression[ix_genes,:][:, ix_samples].T

# Calculate Pearson correlation
gxpred_r = pearson_corr_rowwise(gxpred.sorted_expr_mat.T, sorted_expression.T)

write_r2_dataframe(modelpath, chrom, prior, gxpred_r, gxpred)
# Out:
# Read 641 genes with high r2 values
#
# Found 57 genes in CHR 12
# gxpred-bslmm [0.1, 0.0, 0.1, 0.1, 0.005]
# No prediction found for CHR 1
# No prediction found for CHR 2
# No prediction found for CHR 3
# No prediction found for CHR 4
# No prediction found for CHR 5
# No prediction found for CHR 6
# No prediction found for CHR 7
# No prediction found for CHR 8
# No prediction found for CHR 9
# No prediction found for CHR 10
# No prediction found for CHR 11
# Loaded 57 genes in CHR 12
# 2
# No prediction found for CHR 13
# No prediction found for CHR 14
# No prediction found for CHR 15
# No prediction found for CHR 16
# No prediction found for CHR 17
# No prediction found for CHR 18
# No prediction found for CHR 19
# No prediction found for CHR 20
# No prediction found for CHR 21
# No prediction found for CHR 22
# Genes found: 57 of 57
# Samples found: 338 of 338
# (450, 57)
